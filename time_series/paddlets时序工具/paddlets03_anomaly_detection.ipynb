# %% [markdown]
# # 1、导入数据
#
# 可以直接使用PaddleTS集成的公开数据集，也可以导入自己的数据（如何导入自己的数据请参考TSDataset相关使用文档）
#
# 在这个例子里面，我们使用NAB中的一份温度数据集，NAB是一份比较经典的用于时序异常检测的数据集，详情可参考https://github.com/numenta/NAB
#
# NAB温度数据集已经集成在PaddleTS公开数据集中，可以直接使用下面两行代码导入

# %%
from paddlets.datasets.repository import get_dataset
ts_data = get_dataset('NAB_TEMP')

# %%
ts_data
# Out:
#                      label      value
# timestamp
# 2013-12-02 21:15:00      0  73.967322
# 2013-12-02 21:20:00      0  74.935882
# 2013-12-02 21:25:00      0  76.124162
# 2013-12-02 21:30:00      0  78.140707
# 2013-12-02 21:35:00      0  79.329836
# ...                    ...        ...
# 2014-02-19 15:05:00      0  98.185415
# 2014-02-19 15:10:00      0  97.804168
# 2014-02-19 15:15:00      0  97.135468
# 2014-02-19 15:20:00      0  98.056852
# 2014-02-19 15:25:00      0  96.903861
#
# [22683 rows x 2 columns]

# %% [markdown]
# # 2、数据可视化
#
# 导入数据后，可以通过PaddleTS提供的可视化算子展示数据的具体情况

# %%
#导入可视化算子
from paddlets.utils.utils import plot_anoms
plot_anoms(origin_data=ts_data, feature_name="value")

# %% [markdown]
# # 3、数据预处理
#
# 在正式进行建模之前，确定训练集和测试集（在这个例子中，我们用前15%的数据进行训练，后85%的数据用于测试）
#
# 之后我们对数据进行标准化处理

# %%
from paddlets.transform import StandardScaler
# 据集拆分
train_tsdata, test_tsdata = ts_data.split(0.15)
# 标准化
scaler = StandardScaler()
scaler.fit(train_tsdata)
train_data_scaled = scaler.transform(train_tsdata)
test_data_scaled = scaler.transform(test_tsdata)

# %% [markdown]
# # 4、模型训练
#
# 完成数据预处理之后，我们就可以进行模型训练了，在这个例子中，我们采用AutoEncoder模型对数据进行训练

# %%
import paddle
import numpy as np

# 固定随机随机种子，保证训练结果可复现
seed = 2022
paddle.seed(seed)
np.random.seed(seed)

#建模与训练
from paddlets.models.anomaly import AutoEncoder
model = AutoEncoder(
    in_chunk_len=2, # 样本数据窗口大小
    max_epochs=100  # 最大epoch设为100
)
model.fit(train_data_scaled)
# Out:
# [2022-11-10 16:33:05,775] [paddlets.models.anomaly.dl.anomaly_base] [WARNING] No early stopping will be performed, last training weights will be used.
# [2022-11-10 16:33:06,045] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 000| loss: 0.322022| 0:00:00s
# [2022-11-10 16:33:06,293] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 001| loss: 0.085059| 0:00:00s
# [2022-11-10 16:33:06,533] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 002| loss: 0.064829| 0:00:00s
# [2022-11-10 16:33:06,780] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 003| loss: 0.052350| 0:00:01s
# [2022-11-10 16:33:07,025] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 004| loss: 0.047867| 0:00:01s
# [2022-11-10 16:33:07,273] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 005| loss: 0.045785| 0:00:01s
# [2022-11-10 16:33:07,519] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 006| loss: 0.041525| 0:00:01s
# [2022-11-10 16:33:07,771] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 007| loss: 0.040773| 0:00:01s
# [2022-11-10 16:33:08,021] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 008| loss: 0.040255| 0:00:02s
# [2022-11-10 16:33:08,302] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 009| loss: 0.037563| 0:00:02s
# [2022-11-10 16:33:08,586] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 010| loss: 0.038536| 0:00:02s
# [2022-11-10 16:33:08,844] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 011| loss: 0.035444| 0:00:03s
# [2022-11-10 16:33:09,139] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 012| loss: 0.037201| 0:00:03s
# [2022-11-10 16:33:09,401] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 013| loss: 0.034270| 0:00:03s
# [2022-11-10 16:33:09,660] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 014| loss: 0.032538| 0:00:03s
# [2022-11-10 16:33:09,914] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 015| loss: 0.031376| 0:00:04s
# [2022-11-10 16:33:10,150] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 016| loss: 0.034533| 0:00:04s
# [2022-11-10 16:33:10,423] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 017| loss: 0.033655| 0:00:04s
# [2022-11-10 16:33:10,667] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 018| loss: 0.035307| 0:00:04s
# [2022-11-10 16:33:10,909] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 019| loss: 0.033429| 0:00:05s
# [2022-11-10 16:33:11,141] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 020| loss: 0.038839| 0:00:05s
# [2022-11-10 16:33:11,373] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 021| loss: 0.031429| 0:00:05s
# [2022-11-10 16:33:11,608] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 022| loss: 0.034495| 0:00:05s
# [2022-11-10 16:33:11,843] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 023| loss: 0.030680| 0:00:06s
# [2022-11-10 16:33:12,088] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 024| loss: 0.031617| 0:00:06s
# [2022-11-10 16:33:12,324] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 025| loss: 0.032506| 0:00:06s
# [2022-11-10 16:33:12,576] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 026| loss: 0.031769| 0:00:06s
# [2022-11-10 16:33:12,815] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 027| loss: 0.030166| 0:00:07s
# [2022-11-10 16:33:13,054] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 028| loss: 0.028966| 0:00:07s
# [2022-11-10 16:33:13,287] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 029| loss: 0.029782| 0:00:07s
# [2022-11-10 16:33:13,518] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 030| loss: 0.029776| 0:00:07s
# [2022-11-10 16:33:13,749] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 031| loss: 0.031264| 0:00:07s
# [2022-11-10 16:33:13,983] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 032| loss: 0.026641| 0:00:08s
# [2022-11-10 16:33:14,219] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 033| loss: 0.028022| 0:00:08s
# [2022-11-10 16:33:14,467] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 034| loss: 0.028262| 0:00:08s
# [2022-11-10 16:33:14,703] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 035| loss: 0.029004| 0:00:08s
# [2022-11-10 16:33:14,951] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 036| loss: 0.026842| 0:00:09s
# [2022-11-10 16:33:15,195] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 037| loss: 0.026747| 0:00:09s
# [2022-11-10 16:33:15,439] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 038| loss: 0.026212| 0:00:09s
# [2022-11-10 16:33:15,678] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 039| loss: 0.026938| 0:00:09s
# [2022-11-10 16:33:15,921] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 040| loss: 0.026906| 0:00:10s
# [2022-11-10 16:33:16,167] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 041| loss: 0.028367| 0:00:10s
# [2022-11-10 16:33:16,407] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 042| loss: 0.026251| 0:00:10s
# [2022-11-10 16:33:16,648] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 043| loss: 0.028794| 0:00:10s
# [2022-11-10 16:33:16,889] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 044| loss: 0.026782| 0:00:11s
# [2022-11-10 16:33:17,130] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 045| loss: 0.026549| 0:00:11s
# [2022-11-10 16:33:17,373] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 046| loss: 0.025811| 0:00:11s
# [2022-11-10 16:33:17,618] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 047| loss: 0.026031| 0:00:11s
# [2022-11-10 16:33:17,856] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 048| loss: 0.026768| 0:00:12s
# [2022-11-10 16:33:18,097] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 049| loss: 0.024574| 0:00:12s
# [2022-11-10 16:33:18,350] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 050| loss: 0.027103| 0:00:12s
# [2022-11-10 16:33:18,590] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 051| loss: 0.026240| 0:00:12s
# [2022-11-10 16:33:18,827] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 052| loss: 0.025731| 0:00:13s
# [2022-11-10 16:33:19,064] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 053| loss: 0.026258| 0:00:13s
# [2022-11-10 16:33:19,311] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 054| loss: 0.024798| 0:00:13s
# [2022-11-10 16:33:19,563] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 055| loss: 0.026782| 0:00:13s
# [2022-11-10 16:33:19,799] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 056| loss: 0.026711| 0:00:14s
# [2022-11-10 16:33:20,049] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 057| loss: 0.026483| 0:00:14s
# [2022-11-10 16:33:20,290] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 058| loss: 0.024375| 0:00:14s
# [2022-11-10 16:33:20,533] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 059| loss: 0.025377| 0:00:14s
# [2022-11-10 16:33:20,779] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 060| loss: 0.024400| 0:00:14s
# [2022-11-10 16:33:21,028] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 061| loss: 0.024793| 0:00:15s
# [2022-11-10 16:33:21,274] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 062| loss: 0.025550| 0:00:15s
# [2022-11-10 16:33:21,530] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 063| loss: 0.024305| 0:00:15s
# [2022-11-10 16:33:21,805] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 064| loss: 0.023743| 0:00:16s
# [2022-11-10 16:33:22,062] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 065| loss: 0.025566| 0:00:16s
# [2022-11-10 16:33:22,310] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 066| loss: 0.023745| 0:00:16s
# [2022-11-10 16:33:22,553] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 067| loss: 0.023498| 0:00:16s
# [2022-11-10 16:33:22,787] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 068| loss: 0.024733| 0:00:17s
# [2022-11-10 16:33:23,022] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 069| loss: 0.027064| 0:00:17s
# [2022-11-10 16:33:23,262] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 070| loss: 0.023956| 0:00:17s
# [2022-11-10 16:33:23,507] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 071| loss: 0.024286| 0:00:17s
# [2022-11-10 16:33:23,748] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 072| loss: 0.023708| 0:00:17s
# [2022-11-10 16:33:23,985] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 073| loss: 0.022985| 0:00:18s
# [2022-11-10 16:33:24,406] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 074| loss: 0.024636| 0:00:18s
# [2022-11-10 16:33:24,646] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 075| loss: 0.024472| 0:00:18s
# [2022-11-10 16:33:24,887] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 076| loss: 0.024360| 0:00:19s
# [2022-11-10 16:33:25,142] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 077| loss: 0.023427| 0:00:19s
# [2022-11-10 16:33:25,378] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 078| loss: 0.024432| 0:00:19s
# [2022-11-10 16:33:25,620] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 079| loss: 0.023445| 0:00:19s
# [2022-11-10 16:33:25,852] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 080| loss: 0.024905| 0:00:20s
# [2022-11-10 16:33:26,094] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 081| loss: 0.024188| 0:00:20s
# [2022-11-10 16:33:26,346] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 082| loss: 0.023509| 0:00:20s
# [2022-11-10 16:33:26,624] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 083| loss: 0.022127| 0:00:20s
# [2022-11-10 16:33:26,866] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 084| loss: 0.023102| 0:00:21s
# [2022-11-10 16:33:27,107] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 085| loss: 0.025213| 0:00:21s
# [2022-11-10 16:33:27,347] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 086| loss: 0.023296| 0:00:21s
# [2022-11-10 16:33:27,599] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 087| loss: 0.024503| 0:00:21s
# [2022-11-10 16:33:27,866] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 088| loss: 0.024902| 0:00:22s
# [2022-11-10 16:33:28,165] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 089| loss: 0.023378| 0:00:22s
# [2022-11-10 16:33:28,421] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 090| loss: 0.023701| 0:00:22s
# [2022-11-10 16:33:28,677] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 091| loss: 0.023647| 0:00:22s
# [2022-11-10 16:33:28,926] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 092| loss: 0.023712| 0:00:23s
# [2022-11-10 16:33:29,172] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 093| loss: 0.022150| 0:00:23s
# [2022-11-10 16:33:29,437] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 094| loss: 0.023522| 0:00:23s
# [2022-11-10 16:33:29,688] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 095| loss: 0.021931| 0:00:23s
# [2022-11-10 16:33:29,937] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 096| loss: 0.022152| 0:00:24s
# [2022-11-10 16:33:30,194] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 097| loss: 0.022406| 0:00:24s
# [2022-11-10 16:33:30,472] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 098| loss: 0.023066| 0:00:24s
# [2022-11-10 16:33:30,749] [paddlets.models.common.callbacks.callbacks] [INFO] epoch 099| loss: 0.022656| 0:00:24s

# %% [markdown]
# # 5、模型预测和评估
#
# 模型训练完成之后，可以对测试集进行预测并评估
#
# 评估的指标采用F1,Precision,Recall，PaddleTS已经基于TSDataset实现了这三个指标的计算，直接调用即可

# %%
from paddlets.metrics import F1, Precision, Recall
# 预测
pred_label = model.predict(test_data_scaled)
lable_name = pred_label.target.data.columns[0]
# 计算评估指标 f1, precision, recall
f1 = F1()(test_tsdata, pred_label)
precision = Precision()(test_tsdata, pred_label)
recall = Recall()(test_tsdata, pred_label)
print ('f1: ', f1[lable_name])
print ('precision: ', precision[lable_name])
print ('recall: ', recall[lable_name])
# Out:
# [2022-11-10 16:33:48,036] [paddlets.metrics.base] [WARNING] Tsdataset true's and pred's time_index do not match, the result will be calculated according to the intersection!
# [2022-11-10 16:33:48,055] [paddlets.metrics.base] [WARNING] Tsdataset true's and pred's time_index do not match, the result will be calculated according to the intersection!
# [2022-11-10 16:33:48,072] [paddlets.metrics.base] [WARNING] Tsdataset true's and pred's time_index do not match, the result will be calculated according to the intersection!
# f1:  0.4904181184668989
# precision:  0.946218487394958
# recall:  0.33098177542621987

# %% [markdown]
# # 6、模型结果可视化
#
# 可以将模型的预测结果和真实异常做对比，更加直观的查看模型预测的效果

# %%
# 预测值与真实值
plot_anoms(origin_data=test_tsdata, predict_data=pred_label, feature_name="value")

# %% [markdown]
# 在异常检测场景中，PaddleTS除了提供predict接口预测每个时间点是否异常，还提供了predict_score接口获得每个时间点的异常分数，分数越高，表示该点越可能是异常

# %%
# 异常评分与真实值
pred_score = model.predict_score(test_data_scaled)
plot_anoms(origin_data = test_tsdata, predict_data=pred_score, feature_name = "value")
