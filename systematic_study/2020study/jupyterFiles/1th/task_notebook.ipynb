# %% [markdown]
# # task_notebook - 授人以鱼不如 授人以渔

# %% [markdown]
# ### 环境准备：
# #### jupyter notebook : https://www.jianshu.com/p/91365f343585
# Jupyter Notebook是一块所见即所得的画布，通过在浏览器上编辑代码，让开发人员实现展示与快速迭代的利器。项目最初给予python，通过安装插件，对Javascript也有良好的支持。
# #### 用Python来处理数据分析的优势：https://zhuanlan.zhihu.com/p/88450732
#     - “流程可控，工作高效”
#     - “工具库丰富”
#     - “小白友好，易上手”
# #### python和java区别
#     - Java偏向于商业开发，Python适合于数据分析
#     - Java是一种静态类型语言，Python是一种动态类型语言
#     - 实现同一功能时，JAVA 要敲的键盘次数一般要比 Python 多。
# #### 决策树相关算法介绍：https://blog.csdn.net/qingqing7/article/details/78416708
#
# #### 会议总结
#     - 对机器学习流程有所理解，但不够深入
#     - 数据分析方面，常用方法梳理
#     - 模型准确率影响因素
#         - 算法挑选（没有最好的算法，只有最适合的算法）
#         - 特征值的挑选
#         - 模型训练数据量
#
# #### 如何完成陌生任务
#     - 将 任务 分3块
#         - 1.需求，目标
#         - 2.确定方法，明确步骤，分步骤执行
#         - 3.输出结果与调优
#     - 善用工具
#     - 勤于总结
#     - 积极沟通

# %% [markdown]
# # 目录：
# ### 1.引入依赖包
# ### 2.导入数据
# ### 3.清洗数据
# ### 4.数据分析
# ### 5.数据可视化
# ### 6.再次清洗数据
# ### 7.准备数据
# ### 8.建模、预测和评价
#
# ## 内容：

# %% [markdown]
# ## 1.引入依赖包

# %%
import sys
sys.path
sys.path.append('/usr/local/lib/python3.8/site-packages')

# %%
# 数据分析和准备
import pandas as pd
import numpy as np
import random as rnd

from pandas.api.types import is_string_dtype

# 可视化
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# 当你调用matplotlib.pyplot的绘图函数plot()进行绘图的时候，或者生成一个figure画布的时候，可以直接在你的python console里面生成图像。

# 机器学习
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# %% [markdown]
# ## 2.导入数据
#
# ### 数据集简介：https://www.doc88.com/p-850514714440.html
#
# ### 首先将数据集获取到Pandas DataFrames中。
#
# ### 这里的数据集有以下几个问题：
#  1. 数据集的数据中没有存放特征信息（列名列表），导致直接读取出来的数据会以第一行数据作为列属性。
#     - 这里所做的处理是，在提供的数据集说明文件（bands.names）中找到列名，并将其写入数据文件的第一行中。
#     - 或者，在代码中定义列名的数组，将其赋给读入的数据集文件列名属性
#  2. 数据集在532行出现 错行 现象，该行后8个字段被缩进到了下一行，这里人为在数据集中进行了处理。
#     - 这里所做的处理是，将错乱行数缩进改变，数据集的行数就都统一成了540行。
#     - 或者，不做处理，在后面数据再清洗时删除这两行数据。

# %%
names=['timestamp','cylinder number','customer','job number','grain screened','ink color','proof on ctd ink',
      'blade mfg','cylinder division','paper type','ink type','direct steam','solvent type','type on cylinder',
      'press type','press','unit number','cylinder size','paper mill location','plating tank','proof cut',
      'viscosity','caliper','ink temperature','humifity','roughness','blade pressure','varnish pct','press speed',
      'ink pct','solvent pct','ESA Voltage','ESA Amperage','wax','hardener','roller durometer','current density',
      'anode space ratio','chrome content','band type']

# train_df = pd.read_csv('bands_init.data',names=names)
train_df = pd.read_csv('bands.data')

# %% [markdown]
# #### 这里可以查看一下读取的数据预览（默认前5行和后5行）

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            540 non-null    int64
#  1   cylinder number      540 non-null    object
#  2   customer             540 non-null    object
#  3   job number           540 non-null    int64
#  4   grain screened       540 non-null    object
#  5   ink color            540 non-null    object
#  6   proof on ctd ink     540 non-null    object
#  7   blade mfg            540 non-null    object
#  8   cylinder division    540 non-null    object
#  9   paper type           540 non-null    object
#  10  ink type             540 non-null    object
#  11  direct steam         540 non-null    object
#  12  solvent type         540 non-null    object
#  13  type on cylinder     540 non-null    object
#  14  press type           540 non-null    object
#  15  press                540 non-null    int64
#  16  unit number          540 non-null    int64
#  17  cylinder size        540 non-null    object
#  18  paper mill location  540 non-null    object
#  19  plating tank         540 non-null    object
#  20  proof cut            540 non-null    object
#  21  viscosity            540 non-null    object
#  22  caliper              540 non-null    object
#  23  ink temperature      540 non-null    object
#  24  humifity             540 non-null    object
#  25  roughness            540 non-null    object
#  26  blade pressure       540 non-null    object
#  27  varnish pct          540 non-null    object
#  28  press speed          540 non-null    object
#  29  ink pct              540 non-null    object
#  30  solvent pct          540 non-null    object
#  31  ESA Voltage          540 non-null    object
#  32  ESA Amperage         540 non-null    object
#  33  wax                  540 non-null    object
#  34  hardener             540 non-null    object
#  35  roller durometer     540 non-null    object
#  36  current density      540 non-null    object
#  37  anode space ratio    540 non-null    object
#  38  chrome content       540 non-null    object
#  39  band type            540 non-null    object
# dtypes: int64(4), object(36)
# memory usage: 168.9+ KB

# %% [markdown]
# - 这里可以看一下数据集的数据表

# %%
train_df
# Out:
#      timestamp cylinder number customer  job number grain screened ink color  \
# 0     19910108            X126  TVGUIDE       25503            YES       KEY
# 1     19910109            X266  TVGUIDE       25503            YES       KEY
# 2     19910104              B7   MODMAT       47201            YES       KEY
# 3     19910104            T133   MASSEY       39039            YES       KEY
# 4     19910111             J34    KMART       37351             NO       KEY
# ..         ...             ...      ...         ...            ...       ...
# 535   19941005            aa66    kmart       85813              ?       key
# 536   19941009             j44     best       38064              ?       key
# 537   19941009            aa58    kmart       85814              ?       key
# 538   19941010            aa70    kmart       85814              ?       key
# 539   19941010             j70     best       38064              ?       key
#
#     proof on ctd ink blade mfg cylinder division paper type  ... solvent pct  \
# 0                YES    BENTON          GALLATIN   UNCOATED  ...        36.4
# 1                YES    BENTON          GALLATIN   UNCOATED  ...        38.5
# 2                YES    BENTON          GALLATIN   UNCOATED  ...        39.8
# 3                YES    BENTON          GALLATIN   UNCOATED  ...        38.8
# 4                YES    BENTON          GALLATIN   UNCOATED  ...        42.5
# ..               ...       ...               ...        ...  ...         ...
# 535                ?         ?          gallatin      super  ...           ?
# 536                ?         ?          gallatin      super  ...           ?
# 537                ?         ?          gallatin      super  ...           ?
# 538                ?         ?          gallatin      super  ...           ?
# 539                ?         ?          gallatin      super  ...           ?
#
#     ESA Voltage ESA Amperage  wax hardener  roller durometer  current density  \
# 0             0            0  2.5        1                34               40
# 1             0            0  2.5      0.7                34               40
# 2             0            0  2.8      0.9                40               40
# 3             0            0  2.5      1.3                40               40
# 4             5            0  2.3      0.6                35               40
# ..          ...          ...  ...      ...               ...              ...
# 535           ?            ?    1        1                 ?               40
# 536           ?            ?    0        0                 ?               40
# 537           ?            ?  2.7      2.8                 ?               40
# 538           ?            ?  1.5      2.3                 ?               40
# 539           ?            ?  2.5        1                 ?               40
#
#     anode space ratio chrome content band type
# 0                 105            100      band
# 1                 105            100    noband
# 2              103.87            100    noband
# 3              108.06            100    noband
# 4              106.67            100    noband
# ..                ...            ...       ...
# 535             112.5            100      band
# 536               110            100      band
# 537               108            100      band
# 538               108            100      band
# 539             108.1            100      band
#
# [540 rows x 40 columns]

# %% [markdown]
# ## 3.清洗数据
#
# ### 观察数据，发现以下问题，需对数据做清理
#
#  1. 数据集在某些列，出现 '?' 为标识的数据，这里应该对数据的 '?' 做预处理。
#     - 这里所做的处理是，将 '?' 数据检索到 并替换成 np.nan
#  2. 基于看到的数据，发现数据中存在大小写区分
#     - 这里所做的处理是，统一将str类型的数据转换成小写

# %%
# 把文件中的 ? 替换成 'nan'
# 把文件中 str 类型的值全部转换成小写
temp = 'aa22'
feature_list = train_df.columns.tolist()
for index in train_df.index:
    for feature in feature_list:
        if type(train_df.loc[index, feature]) == type(temp):
            train_df.loc[index, feature] = train_df.loc[index, feature].lower()
        if train_df.loc[index, feature] == '?':
            # print(train_df.loc[index, feature])
            train_df.loc[index, feature] = np.nan

# %% [markdown]
# #### 这里处理完后，可以查看下清洗后的数据

# %%
train_df
# Out:
#      timestamp cylinder number customer  job number grain screened ink color  \
# 0     19910108            x126  tvguide       25503            yes       key
# 1     19910109            x266  tvguide       25503            yes       key
# 2     19910104              b7   modmat       47201            yes       key
# 3     19910104            t133   massey       39039            yes       key
# 4     19910111             j34    kmart       37351             no       key
# ..         ...             ...      ...         ...            ...       ...
# 535   19941005            aa66    kmart       85813            NaN       key
# 536   19941009             j44     best       38064            NaN       key
# 537   19941009            aa58    kmart       85814            NaN       key
# 538   19941010            aa70    kmart       85814            NaN       key
# 539   19941010             j70     best       38064            NaN       key
#
#     proof on ctd ink blade mfg cylinder division paper type  ... solvent pct  \
# 0                yes    benton          gallatin   uncoated  ...        36.4
# 1                yes    benton          gallatin   uncoated  ...        38.5
# 2                yes    benton          gallatin   uncoated  ...        39.8
# 3                yes    benton          gallatin   uncoated  ...        38.8
# 4                yes    benton          gallatin   uncoated  ...        42.5
# ..               ...       ...               ...        ...  ...         ...
# 535              NaN       NaN          gallatin      super  ...         NaN
# 536              NaN       NaN          gallatin      super  ...         NaN
# 537              NaN       NaN          gallatin      super  ...         NaN
# 538              NaN       NaN          gallatin      super  ...         NaN
# 539              NaN       NaN          gallatin      super  ...         NaN
#
#     ESA Voltage ESA Amperage  wax hardener  roller durometer  current density  \
# 0             0            0  2.5        1                34               40
# 1             0            0  2.5      0.7                34               40
# 2             0            0  2.8      0.9                40               40
# 3             0            0  2.5      1.3                40               40
# 4             5            0  2.3      0.6                35               40
# ..          ...          ...  ...      ...               ...              ...
# 535         NaN          NaN    1        1               NaN               40
# 536         NaN          NaN    0        0               NaN               40
# 537         NaN          NaN  2.7      2.8               NaN               40
# 538         NaN          NaN  1.5      2.3               NaN               40
# 539         NaN          NaN  2.5        1               NaN               40
#
#     anode space ratio chrome content band type
# 0                 105            100      band
# 1                 105            100    noband
# 2              103.87            100    noband
# 3              108.06            100    noband
# 4              106.67            100    noband
# ..                ...            ...       ...
# 535             112.5            100      band
# 536               110            100      band
# 537               108            100      band
# 538               108            100      band
# 539             108.1            100      band
#
# [540 rows x 40 columns]

# %% [markdown]
# #### 由上图表可见，' ? ' 数据已统一处理为 NaN，并且 带有字母的字符串数据已统一转换成小写

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            540 non-null    int64
#  1   cylinder number      540 non-null    object
#  2   customer             540 non-null    object
#  3   job number           540 non-null    int64
#  4   grain screened       491 non-null    object
#  5   ink color            540 non-null    object
#  6   proof on ctd ink     483 non-null    object
#  7   blade mfg            480 non-null    object
#  8   cylinder division    540 non-null    object
#  9   paper type           540 non-null    object
#  10  ink type             540 non-null    object
#  11  direct steam         515 non-null    object
#  12  solvent type         485 non-null    object
#  13  type on cylinder     522 non-null    object
#  14  press type           540 non-null    object
#  15  press                540 non-null    int64
#  16  unit number          540 non-null    int64
#  17  cylinder size        537 non-null    object
#  18  paper mill location  384 non-null    object
#  19  plating tank         522 non-null    object
#  20  proof cut            485 non-null    object
#  21  viscosity            535 non-null    object
#  22  caliper              513 non-null    object
#  23  ink temperature      538 non-null    object
#  24  humifity             539 non-null    object
#  25  roughness            510 non-null    object
#  26  blade pressure       477 non-null    object
#  27  varnish pct          484 non-null    object
#  28  press speed          530 non-null    object
#  29  ink pct              484 non-null    object
#  30  solvent pct          484 non-null    object
#  31  ESA Voltage          483 non-null    object
#  32  ESA Amperage         485 non-null    object
#  33  wax                  534 non-null    object
#  34  hardener             533 non-null    object
#  35  roller durometer     485 non-null    object
#  36  current density      533 non-null    object
#  37  anode space ratio    533 non-null    object
#  38  chrome content       537 non-null    object
#  39  band type            540 non-null    object
# dtypes: int64(4), object(36)
# memory usage: 168.9+ KB

# %% [markdown]
# ### 这里的数据还有一个问题：
#  1. 从数据集说明来看，某些列的数据应该为数字类型，但是这里因为有空数据所以 pandas识别成了object类型，无法做数据分析
#     - 这里所做的处理是，将这些数据做类型判断，如果可以转换成数字类型，则转换；否则，不转换

# %%
# 从20列到39列 将列属性转换成float类型
i=20
while(i<39):
    count = 0
    for row in train_df[feature_list[i]]:
        try:
            float(row)
        except ValueError:
            train_df.loc[count,feature_list[i]] = np.nan
            pass
        count=count+1
    train_df[feature_list[i]]=train_df[feature_list[i]].astype(np.float64)
    # 输出转换过的列名
    print(feature_list[i])
    i=i+1
# Out:
# proof cut
# viscosity
# caliper
# ink temperature
# humifity
# roughness
# blade pressure
# varnish pct
# press speed
# ink pct
# solvent pct
# ESA Voltage
# ESA Amperage
# wax
# hardener
# roller durometer
# current density
# anode space ratio
# chrome content

# %% [markdown]
# #### 上面输出的是从object 转成 float类型的列名
#
# #### 下面再来看一下清理以后的数据

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            540 non-null    int64
#  1   cylinder number      540 non-null    object
#  2   customer             540 non-null    object
#  3   job number           540 non-null    int64
#  4   grain screened       491 non-null    object
#  5   ink color            540 non-null    object
#  6   proof on ctd ink     483 non-null    object
#  7   blade mfg            480 non-null    object
#  8   cylinder division    540 non-null    object
#  9   paper type           540 non-null    object
#  10  ink type             540 non-null    object
#  11  direct steam         515 non-null    object
#  12  solvent type         485 non-null    object
#  13  type on cylinder     522 non-null    object
#  14  press type           540 non-null    object
#  15  press                540 non-null    int64
#  16  unit number          540 non-null    int64
#  17  cylinder size        537 non-null    object
#  18  paper mill location  384 non-null    object
#  19  plating tank         522 non-null    object
#  20  proof cut            485 non-null    float64
#  21  viscosity            535 non-null    float64
#  22  caliper              513 non-null    float64
#  23  ink temperature      538 non-null    float64
#  24  humifity             539 non-null    float64
#  25  roughness            510 non-null    float64
#  26  blade pressure       477 non-null    float64
#  27  varnish pct          484 non-null    float64
#  28  press speed          530 non-null    float64
#  29  ink pct              484 non-null    float64
#  30  solvent pct          484 non-null    float64
#  31  ESA Voltage          483 non-null    float64
#  32  ESA Amperage         485 non-null    float64
#  33  wax                  534 non-null    float64
#  34  hardener             533 non-null    float64
#  35  roller durometer     485 non-null    float64
#  36  current density      533 non-null    float64
#  37  anode space ratio    533 non-null    float64
#  38  chrome content       537 non-null    float64
#  39  band type            540 non-null    object
# dtypes: float64(19), int64(4), object(17)
# memory usage: 168.9+ KB

# %% [markdown]
# ## 4.数据分析
#
# #### 输入include=['O']，计算离散型变量的统计特征.
#
# ##### 此图可以看出非空数量count，唯一值种类unique，出现最多的类型top和出现次数freq

# %%
train_df.describe(include=['O'])
# Out:
#        cylinder number customer grain screened ink color proof on ctd ink  \
# count              540      540            491       540              483
# unique             429       71              2         1                2
# top               x129    kmart             no       key              yes
# freq                 5       67            281       540              461
#
#        blade mfg cylinder division paper type ink type direct steam  \
# count        480               540        540      540          515
# unique         2                 1          3        3            2
# top       benton          gallatin   uncoated   coated           no
# freq         479               540        294      291          513
#
#        solvent type type on cylinder press type cylinder size  \
# count           485              522        540           537
# unique            3                2          4             3
# top            line              yes   motter94       tabloid
# freq            468              386        238           299
#
#        paper mill location plating tank band type
# count                  384          522       540
# unique                   5            2         2
# top                northus         1910    noband
# freq                   189          332       312

# %% [markdown]
# ### 这里我们选定 最后一列 band type 作为目标值
# - 首先需要对其值进行划分，将 { band, noband} 格式化为 { 1, 0}

# %%
num_encode = {
    'band type': {'noband':0, "band":1},
}
train_df.replace(num_encode,inplace=True)

# %%
train_df.describe()
# Out:
#           timestamp    job number       press  unit number   proof cut  \
# count  5.400000e+02    540.000000  540.000000   540.000000  485.000000
# mean   1.990780e+07  37287.531481  817.675926     4.877778   45.036082
# std    8.521975e+03   8728.998307    7.444076     3.250784    9.044097
# min    1.990033e+07  23040.000000  802.000000     1.000000   25.000000
# 25%    1.990091e+07  34585.000000  815.000000     2.000000   40.000000
# 50%    1.991012e+07  36062.500000  816.000000     2.000000   45.000000
# 75%    1.991060e+07  37527.500000  824.000000     9.000000   50.000000
# max    1.994101e+07  88231.000000  828.000000    10.000000   72.500000
#
#         viscosity     caliper  ink temperature    humifity   roughness  ...  \
# count  535.000000  513.000000       538.000000  539.000000  510.000000  ...
# mean    50.938318    0.275710        15.362844   78.549165    0.724506  ...
# std      8.055399    0.069487         1.278759    7.731008    0.193354  ...
# min     35.000000    0.133000        11.200000   57.000000    0.056250  ...
# 25%     43.000000    0.200000        14.600000   73.000000    0.625000  ...
# 50%     50.000000    0.267000        15.200000   78.000000    0.750000  ...
# 75%     56.000000    0.300000        16.000000   82.000000    0.812500  ...
# max     72.000000    0.533000        24.500000  105.000000    1.250000  ...
#
#        solvent pct  ESA Voltage  ESA Amperage         wax    hardener  \
# count   484.000000   483.000000    485.000000  534.000000  533.000000
# mean     38.567645     1.319358      0.038144    2.399251    0.987054
# std       3.501431     2.462605      0.415466    0.546427    0.367821
# min      22.000000     0.000000      0.000000    0.000000    0.000000
# 25%      36.800000     0.000000      0.000000    2.400000    0.800000
# 50%      38.500000     0.000000      0.000000    2.500000    1.000000
# 75%      41.200000     2.000000      0.000000    2.600000    1.000000
# max      53.400000    16.000000      6.000000    3.100000    3.000000
#
#        roller durometer  current density  anode space ratio  chrome content  \
# count        485.000000       533.000000         533.000000      537.000000
# mean          34.775258        39.058161         103.044174       99.590317
# std            4.505736         2.351290           5.011135        1.862768
# min           28.000000        30.000000          83.330000       90.000000
# 25%           30.000000        40.000000         100.000000      100.000000
# 50%           34.000000        40.000000         103.130000      100.000000
# 75%           40.000000        40.000000         106.450000      100.000000
# max           60.000000        45.000000         117.860000      100.000000
#
#         band type
# count  540.000000
# mean     0.422222
# std      0.494372
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# - 再来看一下处理后的数据集

# %%
train_df
# Out:
#      timestamp cylinder number customer  job number grain screened ink color  \
# 0     19910108            x126  tvguide       25503            yes       key
# 1     19910109            x266  tvguide       25503            yes       key
# 2     19910104              b7   modmat       47201            yes       key
# 3     19910104            t133   massey       39039            yes       key
# 4     19910111             j34    kmart       37351             no       key
# ..         ...             ...      ...         ...            ...       ...
# 535   19941005            aa66    kmart       85813            NaN       key
# 536   19941009             j44     best       38064            NaN       key
# 537   19941009            aa58    kmart       85814            NaN       key
# 538   19941010            aa70    kmart       85814            NaN       key
# 539   19941010             j70     best       38064            NaN       key
#
#     proof on ctd ink blade mfg cylinder division paper type  ... solvent pct  \
# 0                yes    benton          gallatin   uncoated  ...        36.4
# 1                yes    benton          gallatin   uncoated  ...        38.5
# 2                yes    benton          gallatin   uncoated  ...        39.8
# 3                yes    benton          gallatin   uncoated  ...        38.8
# 4                yes    benton          gallatin   uncoated  ...        42.5
# ..               ...       ...               ...        ...  ...         ...
# 535              NaN       NaN          gallatin      super  ...         NaN
# 536              NaN       NaN          gallatin      super  ...         NaN
# 537              NaN       NaN          gallatin      super  ...         NaN
# 538              NaN       NaN          gallatin      super  ...         NaN
# 539              NaN       NaN          gallatin      super  ...         NaN
#
#     ESA Voltage ESA Amperage  wax hardener  roller durometer  current density  \
# 0           0.0          0.0  2.5      1.0              34.0             40.0
# 1           0.0          0.0  2.5      0.7              34.0             40.0
# 2           0.0          0.0  2.8      0.9              40.0             40.0
# 3           0.0          0.0  2.5      1.3              40.0             40.0
# 4           5.0          0.0  2.3      0.6              35.0             40.0
# ..          ...          ...  ...      ...               ...              ...
# 535         NaN          NaN  1.0      1.0               NaN             40.0
# 536         NaN          NaN  0.0      0.0               NaN             40.0
# 537         NaN          NaN  2.7      2.8               NaN             40.0
# 538         NaN          NaN  1.5      2.3               NaN             40.0
# 539         NaN          NaN  2.5      1.0               NaN             40.0
#
#     anode space ratio chrome content band type
# 0              105.00          100.0         1
# 1              105.00          100.0         0
# 2              103.87          100.0         0
# 3              108.06          100.0         0
# 4              106.67          100.0         0
# ..                ...            ...       ...
# 535            112.50          100.0         1
# 536            110.00          100.0         1
# 537            108.00          100.0         1
# 538            108.00          100.0         1
# 539            108.10          100.0         1
#
# [540 rows x 40 columns]

# %% [markdown]
# ### 数据相关性
#
# #### 这里我们看一下每列和目标 band type 之间的数据相关性
#
#
# #### 离散型数据相关性分析与特征挑选 - https://blog.csdn.net/qingqing7/article/details/78416708

# %%
# .corr是查看连续性变量之间的数据相关性
# 显示各元素间的相关性
# train_df.corr()

# %%
# 筛选出相关性大于0.8且不等于1的数据
# train_df.corr()[(train_df.corr() > 0.8) & (train_df.corr() != 1)]

# %% [markdown]
# ### 查看分类数据和目标值的数据相关性
# - 用循环输出所有分类特征的数据相关数据

# %%
# 查看分类数据和目标值的数据相关性
for feature in feature_list:
    if(feature!='band type'):
        print("################"+feature+"################")
        print(train_df[[feature, 'band type']].groupby([feature], as_index=False).mean().sort_values(by='band type', ascending=False))
# Out:
# ################timestamp################
#      timestamp  band type
# 0     19900330        1.0
# 197   19910618        1.0
# 199   19910622        1.0
# 200   19910626        1.0
# 201   19910627        1.0
# ..         ...        ...
# 183   19910517        0.0
# 179   19910505        0.0
# 174   19910428        0.0
# 96    19901119        0.0
# 148   19910308        0.0
#
# [296 rows x 2 columns]
# ################cylinder number################
#     cylinder number  band type
# 0              1351        1.0
# 120              g5        1.0
# 247            t195        1.0
# 113            g433        1.0
# 114            g459        1.0
# ..              ...        ...
# 273             w30        0.0
# 274            w357        0.0
# 275            w364        0.0
# 91             f629        0.0
# 214             o28        0.0
#
# [429 rows x 2 columns]
# ################customer################
#         customer  band type
# 70    yieldhouse        1.0
# 65       venture        1.0
# 53   ntlwildlife        1.0
# 45       kidsrus        1.0
# 44           jfk        1.0
# ..           ...        ...
# 13     casliving        0.0
# 12  campingworld        0.0
# 7          belks        0.0
# 2      abbypress        0.0
# 35    hanoverhse        0.0
#
# [71 rows x 2 columns]
# ################job number################
#      job number  band type
# 0         23040        1.0
# 64        34514        1.0
# 120       35661        1.0
# 116       35528        1.0
# 114       35522        1.0
# ..          ...        ...
# 127       35759        0.0
# 128       35761        0.0
# 129       35794        0.0
# 1         23048        0.0
# 261       88231        0.0
#
# [262 rows x 2 columns]
# ################grain screened################
#   grain screened  band type
# 1            yes   0.471429
# 0             no   0.298932
# ################ink color################
#   ink color  band type
# 0       key   0.422222
# ################proof on ctd ink################
#   proof on ctd ink  band type
# 1              yes   0.364425
# 0               no   0.227273
# ################blade mfg################
#   blade mfg  band type
# 0    benton   0.359081
# 1  uddeholm   0.000000
# ################cylinder division################
#   cylinder division  band type
# 0          gallatin   0.422222
# ################paper type################
#   paper type  band type
# 1      super   1.000000
# 2   uncoated   0.445578
# 0     coated   0.331839
# ################ink type################
#    ink type  band type
# 1     cover   0.888889
# 2  uncoated   0.506494
# 0    coated   0.326460
# ################direct steam################
#   direct steam  band type
# 0           no   0.395712
# 1          yes   0.000000
# ################solvent type################
#   solvent type  band type
# 2        xylol   0.400000
# 0         line   0.356838
# 1       naptha   0.000000
# ################type on cylinder################
#   type on cylinder  band type
# 0               no   0.507353
# 1              yes   0.380829
# ################press type################
#   press type  band type
# 3  woodhoe70   0.545455
# 0   albert70   0.461538
# 2   motter94   0.365546
# 1   motter70   0.187500
# ################press################
#    press  band type
# 2    815   0.651685
# 4    821   0.584416
# 3    816   0.524272
# 0    802   0.322581
# 6    827   0.305085
# 5    824   0.238095
# 7    828   0.230769
# 1    813   0.187500
# ################unit number################
#    unit number  band type
# 4            7   0.611765
# 0            1   0.500000
# 1            2   0.441296
# 5            9   0.310811
# 3            6   0.250000
# 6           10   0.222222
# 2            5   0.076923
# ################cylinder size################
#   cylinder size  band type
# 1       spiegel   0.466667
# 2       tabloid   0.414716
# 0       catalog   0.410112
# ################paper mill location################
#   paper mill location  band type
# 4             southus   0.750000
# 1         mideuropean   0.400000
# 2             northus   0.370370
# 0            canadian   0.257862
# 3        scandanavian   0.230769
# ################plating tank################
#   plating tank  band type
# 1         1911   0.447368
# 0         1910   0.409639
# ################proof cut################
#     proof cut  band type
# 13       49.0   1.000000
# 15       52.0   0.750000
# 12       47.5   0.590909
# 17       55.0   0.548387
# 24       67.5   0.500000
# 22       62.5   0.500000
# 21       62.0   0.500000
# 14       50.0   0.473684
# 5        35.0   0.441176
# 9        42.5   0.416667
# 7        40.0   0.414414
# 8        42.0   0.333333
# 10       45.0   0.310345
# 23       65.0   0.307692
# 20       60.0   0.227273
# 4        32.5   0.222222
# 6        37.5   0.187500
# 2        30.0   0.176471
# 16       52.5   0.166667
# 25       70.0   0.000000
# 0        25.0   0.000000
# 19       57.5   0.000000
# 18       55.5   0.000000
# 1        27.5   0.000000
# 11       47.0   0.000000
# 3        32.0   0.000000
# 26       72.5   0.000000
# ################viscosity################
#     viscosity  band type
# 36       72.0   1.000000
# 31       66.0   1.000000
# 28       63.0   1.000000
# 1        36.0   1.000000
# 30       65.0   0.777778
# 17       52.0   0.750000
# 33       68.0   0.714286
# 14       49.0   0.615385
# 5        40.0   0.611111
# 4        39.0   0.571429
# 12       47.0   0.571429
# 25       60.0   0.523810
# 32       67.0   0.500000
# 29       64.0   0.500000
# 0        35.0   0.500000
# 11       46.0   0.470588
# 24       59.0   0.444444
# 7        42.0   0.441176
# 21       56.0   0.441176
# 20       55.0   0.437500
# 15       50.0   0.433333
# 16       51.0   0.428571
# 22       57.0   0.400000
# 10       45.0   0.380952
# 27       62.0   0.375000
# 23       58.0   0.368421
# 8        43.0   0.340909
# 34       69.0   0.333333
# 18       53.0   0.333333
# 13       48.0   0.277778
# 9        44.0   0.266667
# 26       61.0   0.250000
# 3        38.0   0.222222
# 6        41.0   0.210526
# 19       54.0   0.156863
# 2        37.0   0.000000
# 35       70.0   0.000000
# ################caliper################
#     caliper  band type
# 0     0.133   1.000000
# 3     0.217   1.000000
# 5     0.250   1.000000
# 1     0.167   0.600000
# 11    0.367   0.535714
# 7     0.283   0.500000
# 10    0.350   0.500000
# 8     0.300   0.495050
# 6     0.267   0.420290
# 2     0.200   0.406015
# 15    0.500   0.400000
# 12    0.400   0.391304
# 4     0.233   0.342466
# 13    0.433   0.300000
# 9     0.333   0.235294
# 14    0.467   0.000000
# 16    0.533   0.000000
# ################ink temperature################
#     ink temperature  band type
# 0             11.20        1.0
# 15            13.90        1.0
# 63            22.20        1.0
# 62            21.00        1.0
# 60            18.50        1.0
# ..              ...        ...
# 49            16.53        0.0
# 33            15.40        0.0
# 7             13.30        0.0
# 29            15.03        0.0
# 8             13.34        0.0
#
# [65 rows x 2 columns]
# ################humifity################
#     humifity  band type
# 41     105.0   1.000000
# 24      83.0   0.750000
# 30      89.0   0.750000
# 39     100.0   0.714286
# 14      73.0   0.700000
# 36      95.0   0.666667
# 35      94.0   0.666667
# 33      92.0   0.600000
# 26      85.0   0.578947
# 27      86.0   0.545455
# 19      78.0   0.541667
# 13      72.0   0.517241
# 12      71.0   0.500000
# 34      93.0   0.500000
# 2       60.0   0.500000
# 23      82.0   0.481481
# 17      76.0   0.470588
# 28      87.0   0.444444
# 31      90.0   0.416667
# 18      77.0   0.400000
# 38      98.0   0.400000
# 25      84.0   0.400000
# 16      75.0   0.388889
# 11      70.0   0.377358
# 21      80.0   0.367089
# 15      74.0   0.347826
# 29      88.0   0.333333
# 32      91.0   0.333333
# 20      79.0   0.307692
# 6       65.0   0.285714
# 22      81.0   0.250000
# 5       64.0   0.142857
# 9       68.0   0.083333
# 37      96.0   0.000000
# 40     103.0   0.000000
# 3       62.0   0.000000
# 4       63.0   0.000000
# 8       67.0   0.000000
# 7       66.0   0.000000
# 1       58.0   0.000000
# 10      69.0   0.000000
# 0       57.0   0.000000
# ################roughness################
#     roughness  band type
# 0     0.05625   1.000000
# 16    1.12500   0.666667
# 8     0.62500   0.546392
# 6     0.50000   0.542857
# 1     0.18750   0.500000
# 2     0.25000   0.500000
# 5     0.43750   0.500000
# 4     0.37500   0.444444
# 15    1.00000   0.434211
# 9     0.75000   0.420765
# 13    0.87500   0.375000
# 14    0.93750   0.333333
# 7     0.56250   0.266667
# 3     0.31250   0.250000
# 11    0.81250   0.235294
# 10    0.81200   0.000000
# 12    0.81750   0.000000
# 17    1.25000   0.000000
# ################blade pressure################
#     blade pressure  band type
# 0             16.0   1.000000
# 1             18.0   1.000000
# 28            49.0   1.000000
# 18            36.0   1.000000
# 35            70.0   1.000000
# 4             22.0   0.727273
# 9             27.0   0.714286
# 11            29.0   0.666667
# 15            33.0   0.666667
# 20            40.0   0.642857
# 34            60.0   0.600000
# 17            35.0   0.578947
# 14            32.0   0.565217
# 22            42.0   0.500000
# 8             26.0   0.500000
# 10            28.0   0.500000
# 30            52.0   0.500000
# 5             23.0   0.500000
# 7             25.0   0.460000
# 12            30.0   0.446281
# 16            34.0   0.428571
# 31            55.0   0.428571
# 6             24.0   0.416667
# 29            50.0   0.333333
# 2             20.0   0.258621
# 24            45.0   0.250000
# 19            38.0   0.166667
# 23            43.0   0.000000
# 25            46.0   0.000000
# 26            47.0   0.000000
# 27            48.0   0.000000
# 3             21.0   0.000000
# 32            56.0   0.000000
# 33            58.0   0.000000
# 13            31.0   0.000000
# 21            41.0   0.000000
# ################varnish pct################
#      varnish pct  band type
# 121         35.8        1.0
# 95          17.1        1.0
# 47           8.8        1.0
# 52           9.5        1.0
# 36           7.2        1.0
# ..           ...        ...
# 26           5.7        0.0
# 69          11.5        0.0
# 68          11.3        0.0
# 67          11.2        0.0
# 21           5.1        0.0
#
# [122 rows x 2 columns]
# ################press speed################
#     press speed  band type
# 0           0.0        1.0
# 42       1742.0        1.0
# 26       1565.0        1.0
# 27       1570.0        1.0
# 29       1620.0        1.0
# ..          ...        ...
# 38       1725.0        0.0
# 39       1726.0        0.0
# 47       1835.0        0.0
# 51       1875.0        0.0
# 82       2600.0        0.0
#
# [83 rows x 2 columns]
# ################ink pct################
#     ink pct  band type
# 80     76.9        1.0
# 72     63.3        1.0
# 34     53.0        1.0
# 36     53.4        1.0
# 21     48.7        1.0
# ..      ...        ...
# 42     55.0        0.0
# 56     58.5        0.0
# 48     56.7        0.0
# 53     58.0        0.0
# 0      41.0        0.0
#
# [81 rows x 2 columns]
# ################solvent pct################
#      solvent pct  band type
# 114         53.4        1.0
# 109         46.1        1.0
# 44          36.7        1.0
# 100         43.8        1.0
# 35          35.8        1.0
# ..           ...        ...
# 70          39.6        0.0
# 71          39.7        0.0
# 77          40.6        0.0
# 80          40.9        0.0
# 57          38.2        0.0
#
# [115 rows x 2 columns]
# ################ESA Voltage################
#     ESA Voltage  band type
# 16        16.00   1.000000
# 2          0.75   1.000000
# 6          2.50   1.000000
# 3          1.00   0.791667
# 4          1.50   0.500000
# 5          2.00   0.393939
# 7          3.00   0.391304
# 0          0.00   0.356250
# 8          4.00   0.344828
# 10         5.00   0.150000
# 12         8.00   0.111111
# 1          0.50   0.000000
# 9          4.50   0.000000
# 11         6.00   0.000000
# 13         9.00   0.000000
# 14        10.00   0.000000
# 15        12.00   0.000000
# ################ESA Amperage################
#    ESA Amperage  band type
# 0           0.0   0.358333
# 2           4.0   0.333333
# 1           0.5   0.000000
# 3           6.0   0.000000
# ################wax################
#      wax  band type
# 0   0.00   1.000000
# 1   0.50   1.000000
# 27  2.90   0.727273
# 16  2.10   0.625000
# 13  1.80   0.600000
# 22  2.60   0.545455
# 2   0.70   0.500000
# 7   1.30   0.500000
# 21  2.50   0.466135
# 23  2.70   0.437500
# 20  2.40   0.416667
# 19  2.30   0.363636
# 9   1.50   0.350000
# 15  2.00   0.342857
# 6   1.20   0.333333
# 25  2.80   0.333333
# 28  3.00   0.333333
# 17  2.20   0.285714
# 4   1.00   0.222222
# 11  1.70   0.125000
# 14  1.90   0.000000
# 12  1.75   0.000000
# 18  2.25   0.000000
# 10  1.60   0.000000
# 8   1.40   0.000000
# 5   1.10   0.000000
# 24  2.75   0.000000
# 26  2.85   0.000000
# 3   0.80   0.000000
# 29  3.10   0.000000
# ################hardener################
#     hardener  band type
# 0       0.00   1.000000
# 2       0.30   1.000000
# 27      2.80   1.000000
# 6       0.65   1.000000
# 24      2.20   1.000000
# 23      2.10   1.000000
# 1       0.20   0.666667
# 19      1.50   0.533333
# 12      1.00   0.510309
# 15      1.25   0.500000
# 26      2.50   0.500000
# 25      2.30   0.500000
# 22      2.00   0.500000
# 20      1.70   0.500000
# 18      1.40   0.500000
# 14      1.20   0.473684
# 16      1.30   0.347826
# 10      0.85   0.333333
# 11      0.90   0.319149
# 4       0.50   0.291667
# 9       0.80   0.285714
# 13      1.10   0.280000
# 5       0.60   0.258065
# 7       0.70   0.250000
# 21      1.80   0.200000
# 3       0.40   0.200000
# 17      1.35   0.000000
# 8       0.75   0.000000
# 28      3.00   0.000000
# ################roller durometer################
#     roller durometer  band type
# 10              50.0   1.000000
# 6               38.0   0.619048
# 4               34.0   0.509434
# 9               45.0   0.500000
# 8               40.0   0.416000
# 5               35.0   0.355932
# 1               30.0   0.292308
# 2               32.0   0.222222
# 3               33.0   0.212121
# 0               28.0   0.090909
# 7               38.5   0.000000
# 11              60.0   0.000000
# ################current density################
#    current density  band type
# 3             37.0   1.000000
# 4             40.0   0.464037
# 1             33.0   0.380952
# 0             30.0   0.333333
# 2             35.0   0.171875
# 5             42.0   0.000000
# 6             45.0   0.000000
# ################anode space ratio################
#     anode space ratio  band type
# 0              83.330        1.0
# 24            102.770        1.0
# 26            102.940        1.0
# 27            102.941        1.0
# 28            103.000        1.0
# ..                ...        ...
# 54            106.700        0.0
# 9              94.117        0.0
# 56            106.900        0.0
# 11             96.600        0.0
# 50            106.500        0.0
#
# [80 rows x 2 columns]
# ################chrome content################
#    chrome content  band type
# 1            95.0   1.000000
# 0            90.0   0.529412
# 2           100.0   0.403922

# %%
# 测试---
# 复制并插入一列
# copy_list = []
# copy_list = train_df[['band type']]
# train_df.insert(40, 'copy_list', copy_list)   

# print(train_df[['ink type', 'band type']].groupby(['ink type'], as_index=False).mean())

# %%
# 测试---
# num_encode = {
#     'copy_list': {0:'noband', 1:"band"},
# }
# train_df.replace(num_encode,inplace=True)

# %%
# train_df

# %%
# 测试---
# train_df.iloc[0,40] = 'band'
# train_df.iloc[0,40]

# %%
# 测试---
# print(train_df[['copy_list', 'band type']].groupby(['copy_list'], as_index=False).mean())

# %%
# 测试---
# train_df[['copy_list', 'band type']].groupby(['copy_list'], as_index=False)

# %% [markdown]
# #### 从上述结果可以看出，
# grain screened, blade mfg,paper type,ink type, direct steam
# 这些列与目标存在相关性。

# %% [markdown]
# ## 5.数据可视化
#
# #### 这里我们将刚刚分析出来的与目标相关的特征数据可视化
#
# - 这里碰到一个问题，画图时，当数据有空值会导致画图失败
# - 这里的解决办法是，在用众数填充空值后，再画图去分析。

# %%
# 绘画折线图：
# sns.lineplot(x='grain screened', y='band type', data=train_df)
# sns.lineplot(x='grain screened', y='band type', data=train_df)

# g = sns.FacetGrid(train_df, col='band type')
# g.map(plt.hist, 'grain screened', bins=20)

# %%
# 绘画散点图：
x = train_df['paper type']
y = train_df['band type']
color = ['r','y','k','g','m']
plt.scatter(x, y)
plt.show()

# %%
# sns.lineplot(x='grain screened', y='band type', data=train_df)

# %%
# sns.lineplot(x='blade mfg', y='band type', data=train_df)

# g = sns.FacetGrid(train_df, col='band type')
# g.map(plt.hist, 'blade mfg', bins=20)

# %%
sns.lineplot(x='paper type', y='band type', data=train_df)
# g = sns.FacetGrid(train_df, col='paper type')
# g.map(plt.hist, 'paper type', bins=20)

# %%
# sns.lineplot(x='ink type', y='band type', data=train_df)

# g = sns.FacetGrid(train_df, col='ink type')
# g.map(plt.hist, 'ink type', bins=20)

# %%
# sns.lineplot(x='direct steam', y='band type', data=train_df)

# g = sns.FacetGrid(train_df, col='direct steam')
# g.map(plt.hist, 'direct steam', bins=20)

# %% [markdown]
# #### 这里是连续变量的相关性画图，因为该决策树算法只用到了分类数据，所以这里只例举一个特征，其余的同理。

# %%
# viscosity
g = sns.FacetGrid(train_df, col='band type')
g.map(plt.hist, 'viscosity', bins=20)

# %%
# humifity
# ink temperature
# proof cut
# roughness
# blade pressure
# varnish pct
# press speed
# ink pct
# solvent pct
# ESA Voltage
# ESA Amperage
# wax
# hardener
# roller durometer
# current density
# anode space ratio
# chrome content

# %% [markdown]
# ## 6.再次清洗数据

# %% [markdown]
# #### 首先看下当前数据集的 行和列 数目

# %%
train_df.shape

# %% [markdown]
# 当前数据集中，存在目标值 band type 为空的数据， 应该删除这些错误数据

# %%
for index in range(train_df.shape[0]):
    try:
        if np.isnan(train_df['band type'][index]):
            train_df=train_df.drop([index])
    except:
        pass
train_df.info()

# %% [markdown]
# ### 用众数，填充空数据

# %%
for item in train_df.columns.values.tolist():
    if train_df[item].dtype == object:
        train_df[item].fillna(train_df[item].mode(dropna=True)[0], inplace=True)
# 数字类型也填充
    if train_df[item].dtype == float:
        train_df[item].fillna(train_df[item].mode(dropna=True)[0], inplace=True)
train_df.info()

# %% [markdown]
# ### 数据可视化
# #### 折线图表现特征与目标直接的关系

# %%
train_df.info()

# %%
sns.lineplot(x='grain screened', y='band type', data=train_df)

# %%
sns.lineplot(x='ink color', y='band type', data=train_df)

# %%
sns.lineplot(x='proof on ctd ink', y='band type', data=train_df)

# %%
sns.lineplot(x='blade mfg', y='band type', data=train_df)

# %%
sns.lineplot(x='cylinder division', y='band type', data=train_df)

# %%
sns.lineplot(x='paper type', y='band type', data=train_df)

# %%
sns.lineplot(x='ink type', y='band type', data=train_df)

# %%
sns.lineplot(x='direct steam', y='band type', data=train_df)

# %%
sns.lineplot(x='solvent type', y='band type', data=train_df)

# %%
sns.lineplot(x='type on cylinder', y='band type', data=train_df)

# %%
sns.lineplot(x='press type', y='band type', data=train_df)

# %%
sns.lineplot(x='cylinder size', y='band type', data=train_df)

# %%
sns.lineplot(x='paper mill location', y='band type', data=train_df)

# %%
sns.lineplot(x='plating tank', y='band type', data=train_df)

# %% [markdown]
# groupBy(A)：A列中重复的值和成同一个值，然后把A当成索引来进行重新的数据分组

# %%
# 查看分类数据和目标值的数据相关性
for feature in feature_list:
    if(feature!='band type'):
        print("################"+feature+"################")
        print(train_df[[feature, 'band type']].groupby([feature], as_index=False).mean().sort_values(by='band type', ascending=False))

# %% [markdown]
# ## 7.准备数据
#
# ### 把分类数据用数字类型的map替换，方便计算
#
# ### 这里map定义的大些，在特征选择时可从map中选定几个去训练

# %%
encode = {
    'grain screened':{'yes':0,'no':1},
    'proof on ctd ink':{'yes':0,'no':1},
    'blade mfg':{'uddeholm':0,'benton':1},
    'paper type':{'coated':0,'uncoated':1,'super':2},
    'ink type':{'coated':0,'uncoated':1,'cover':2}, 
    'direct steam':{'yes':0,'no':1},
    'type on cylinder':{'yes':0,'no':1},
    'plating tank':{'1911':0,'1910':1},
    'solvent type':{'naptha':0,'line':1,'xylol':2},
    'press type':{'motter70':0,'motter94':1,'albert70':2,'woodhoe70':3},
    'paper mill location':{'scandanavian':0,'canadian':1,'northus':2,'mideuropean':3,'southus':4}
}
train_df.replace(encode, inplace=True)

# %%
train_df

# %% [markdown]
# ### 特征与目标选取
# - 把所有重要的特征放到一个dataframe中，把目标放到一个series中。
#
# - 决策树算法特征挑选 - https://blog.csdn.net/qingqing7/article/details/78416708

# %%
X = train_df[['grain screened','blade mfg','direct steam','paper type', 'ink type','press type','solvent type']]
# X = train_df[['grain screened','blade mfg','direct steam','type on cylinder','plating tank']]
y = train_df['band type']

# %% [markdown]
# ### 划分数据集
# - 将数据集分成30%验证数据，70%训练数据

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
y_test

# %% [markdown]
# ## 8.模型和预测

# %%
tree = DecisionTreeClassifier(criterion='entropy')

# %%
tree.fit(x_train, y_train)
y_pred = tree.predict(x_test)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
